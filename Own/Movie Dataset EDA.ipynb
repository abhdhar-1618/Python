# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('movies_eda.csv', encoding='latin-1')

# %%
data.head()
# Out:
#                   Title  Year Certification/Rating    IMDb ID   Released  \
# 0       Sharey Chuattar  1953                  NaN  tt0046304  20-Feb-53
# 1       The Red Balloon  1956            Not Rated  tt0048980  11-Mar-57
# 2             Moby Dick  1956            Not Rated  tt0049513  29-Aug-56
# 3          12 Angry Men  1957             Approved  tt0050083  10-Apr-57
# 4  The Guns of Navarone  1961            Not Rated  tt0054953  28-Apr-61
#
#    Runtime                     Genre          Director              Writer  \
# 0   98 min           Comedy, Romance        Nirmal Dey  Bijon Bhattacharya
# 1   34 min      Short, Comedy, Drama  Albert Lamorisse    Albert Lamorisse
# 2  116 min          Adventure, Drama       John Huston        Ray Bradbury
# 3   96 min              Crime, Drama      Sidney Lumet       Reginald Rose
# 4  158 min  Action, Adventure, Drama   J. Lee Thompson    Alistair MacLean
#
#                                               Actors  ...  \
# ...

# %%
data.columns
# Out:
# Index(['Title', 'Year', 'Certification/Rating', 'IMDb ID', 'Released',
#        'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Keywords',
#        'Language', 'Country', 'Industry', 'Awards', 'Poster', 'Metascore',
#        'IMDb Rating', 'IMDb Votes', 'Type', 'DVD', 'Box Office', 'Production',
#        'Website'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Title                    object
# Year                     object
# Certification/Rating     object
# IMDb ID                  object
# Released                 object
# Runtime                  object
# Genre                    object
# Director                 object
# Writer                   object
# Actors                   object
# Plot                     object
# Keywords                 object
# Language                 object
# Country                  object
# Industry                 object
# Awards                   object
# Poster                   object
# Metascore               float64
# IMDb Rating             float64
# IMDb Votes               object
# Type                     object
# DVD                      object
# Box Office               object
# Production               object
# Website                  object
# dtype: object

# %%
data['Runtime'] = data['Runtime'].str.replace('min', '').astype(float)

# %%
data.head()
# Out:
#                   Title  Year Certification/Rating    IMDb ID   Released  \
# 0       Sharey Chuattar  1953                  NaN  tt0046304  20-Feb-53
# 1       The Red Balloon  1956            Not Rated  tt0048980  11-Mar-57
# 2             Moby Dick  1956            Not Rated  tt0049513  29-Aug-56
# 3          12 Angry Men  1957             Approved  tt0050083  10-Apr-57
# 4  The Guns of Navarone  1961            Not Rated  tt0054953  28-Apr-61
#
#    Runtime                     Genre          Director              Writer  \
# 0     98.0           Comedy, Romance        Nirmal Dey  Bijon Bhattacharya
# 1     34.0      Short, Comedy, Drama  Albert Lamorisse    Albert Lamorisse
# 2    116.0          Adventure, Drama       John Huston        Ray Bradbury
# 3     96.0              Crime, Drama      Sidney Lumet       Reginald Rose
# 4    158.0  Action, Adventure, Drama   J. Lee Thompson    Alistair MacLean
#
#                                               Actors  ...  \
# ...

# %%
data.dtypes
# Out:
# Title                    object
# Year                     object
# Certification/Rating     object
# IMDb ID                  object
# Released                 object
# Runtime                 float64
# Genre                    object
# Director                 object
# Writer                   object
# Actors                   object
# Plot                     object
# Keywords                 object
# Language                 object
# Country                  object
# Industry                 object
# Awards                   object
# Poster                   object
# Metascore               float64
# IMDb Rating             float64
# IMDb Votes               object
# Type                     object
# DVD                      object
# Box Office               object
# Production               object
# Website                  object
# dtype: object

# %%
data['Runtime_buckets'], bins = pd.qcut(data['Runtime'], q=5, retbins=True, duplicates='drop')

# %%
# Print the bins to see the edges
print("Bins:", bins)

# Print the DataFrame to see the new 'Runtime_buckets' column
print(data[['Runtime', 'Runtime_buckets']])
# Out:
# Bins: [  1. 100. 112. 124. 138. 321.]
#       Runtime Runtime_buckets
# 0        98.0  (0.999, 100.0]
# 1        34.0  (0.999, 100.0]
# 2       116.0  (112.0, 124.0]
# 3        96.0  (0.999, 100.0]
# 4       158.0  (138.0, 321.0]
# ...       ...             ...
# 1137    120.0  (112.0, 124.0]
# 1138     82.0  (0.999, 100.0]
# 1139    107.0  (100.0, 112.0]
# 1140    124.0  (112.0, 124.0]
# 1141    114.0  (112.0, 124.0]
#
# [1142 rows x 2 columns]

# %%
data.dtypes
# Out:
# Title                     object
# Year                      object
# Certification/Rating      object
# IMDb ID                   object
# Released                  object
# Runtime                  float64
# Genre                     object
# Director                  object
# Writer                    object
# Actors                    object
# Plot                      object
# Keywords                  object
# Language                  object
# Country                   object
# Industry                  object
# Awards                    object
# Poster                    object
# Metascore                float64
# IMDb Rating              float64
# IMDb Votes                object
# Type                      object
# DVD                       object
# Box Office                object
# Production                object
# Website                   object
# Runtime_buckets         category
# dtype: object

# %%
# Create a histogram
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.hist(data['Runtime'], bins=20, color='skyblue', edgecolor='black')  # Adjust the number of bins as needed
plt.title('Histogram of Runtime')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Count the number of movies for each unique runtime
runtime_counts = data['Runtime'].value_counts()

# Print the count of movies for each unique runtime
print("Count of movies for each unique runtime:")
print(runtime_counts)
# Out:
# Count of movies for each unique runtime:
# Runtime
# 124.0    32
# 109.0    28
# 130.0    26
# 107.0    23
# 116.0    22
#          ..
# 194.0     1
# 34.0      1
# 202.0     1
# 175.0     1
# 238.0     1
# Name: count, Length: 128, dtype: int64

# %%
# Set pandas display options to show all rows
pd.set_option('display.max_rows', None)

# Count the number of movies for each unique runtime

runtime_counts = data['Runtime'].value_counts()

# Print the count of movies for each unique runtime

print("Count of movies for each unique runtime:")

print(runtime_counts)
# Out:
# Count of movies for each unique runtime:
# Runtime
# 124.0    32
# 109.0    28
# 130.0    26
# 107.0    23
# 116.0    22
# 129.0    21
# 101.0    20
# 122.0    20
# 105.0    20
# 115.0    19
# 110.0    19
# 112.0    19
# 113.0    19
# 104.0    19
# 100.0    19
# 135.0    18
# 103.0    18
# 126.0    18
# 127.0    18
# 138.0    18
# 120.0    18
# 96.0     18
# 128.0    17
# 99.0     17
# 118.0    16
# 131.0    16
# 114.0    16
# 136.0    16
# 93.0     16
# 121.0    16
# 106.0    16
# 108.0    16
# 123.0    16
# 117.0    16
# 119.0    16
# 97.0     15
# 102.0    15
# 134.0    15
# 132.0    15
# 98.0     15
# 141.0    13
# 95.0     13
# 137.0    12
# 133.0    12
# 111.0    12
# 90.0     12
# 143.0    11
# 148.0    11
# 94.0     11
# 91.0     11
# 144.0    10
# 140.0    10
# 125.0    10
# 150.0     9
# 155.0     9
# 149.0     9
# 92.0      9
# 151.0     8
# 146.0     8
# 139.0     8
# 82.0      8
# 145.0     8
# 142.0     8
# 80.0      7
# 163.0     6
# 154.0     6
# 88.0      6
# ...

# %%
# Data type inspection
print("Data Types:")
print(data.dtypes)

# Unique value count
print("\nUnique Value Count:")
for column in data.columns:
    print(f"{column}: {data[column].nunique()} unique values")

# Statistical summary for numerical columns
print("\nStatistical Summary for Numerical Columns:")
print(data.describe())

# Visualization (Histogram for numerical columns, Count plot for categorical columns)
# Example for histogram
numerical_columns = data.select_dtypes(include=['int', 'float']).columns
for column in numerical_columns:
    data[column].hist()
    plt.title(column)
    plt.show()

# Example for count plot
categorical_columns = data.select_dtypes(include=['object', 'category']).columns
for column in categorical_columns:
    if data[column].nunique() < 20:  # Adjust the threshold as needed
        try:
            sns.countplot(data[column])
            plt.title(column)
            plt.show()
        except ValueError as e:
            print(f"Error plotting column '{column}': {e}")
# Out:
# Data Types:
# Title                     object
# Year                      object
# Certification/Rating      object
# IMDb ID                   object
# Released                  object
# Runtime                  float64
# Genre                     object
# Director                  object
# Writer                    object
# Actors                    object
# Plot                      object
# Keywords                  object
# Language                  object
# Country                   object
# Industry                  object
# Awards                    object
# Poster                    object
# Metascore                float64
# IMDb Rating              float64
# IMDb Votes                object
# Type                      object
# DVD                       object
# Box Office                object
# Production                object
# Website                   object
# Runtime_buckets         category
# dtype: object
#
# Unique Value Count:
# Title: 1138 unique values
# ...

# %%
# Drop non-numeric columns
numeric_data = data.select_dtypes(include=['int', 'float'])

# Compute the correlation matrix
corr_matrix = numeric_data.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Plot')
plt.show()
