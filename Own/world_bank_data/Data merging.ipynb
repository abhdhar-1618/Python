# %%
import pandas as pd

# %%
df = pd.read_csv('gdp.csv')

# %%
df.head(3)
# Out:
#                     Series Name     Series Code Country Name Country Code  \
# 0  GDP per capita (current US$)  NY.GDP.PCAP.CD  Afghanistan          AFG
# 1  GDP per capita (current US$)  NY.GDP.PCAP.CD      Albania          ALB
# 2  GDP per capita (current US$)  NY.GDP.PCAP.CD      Algeria          DZA
#
#       1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 0  62.3693745050559  62.4437034626929  60.9503638210144  82.0217375781519
# 1                ..                ..                ..                ..
# 2  239.033005807284  209.917177642367  169.927013321055  225.823391368412
#
#       1964 [YR1964]     1965 [YR1965]  ...     2014 [YR2014]  \
# 0  85.5110734102311  105.243195716467  ...  626.512930450573
# 1                ..                ..  ...  4578.63320812155
# 2  238.877804941679  253.309059020723  ...  5516.22944039649
#
#       2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# ...

# %%
# List of column names to remove
columns_to_remove = ['Series Name', 'Series Code']

# %%
# Remove columns by name
df_t1 = df.drop(columns=columns_to_remove)

# %%
df_t1.head(3)
# Out:
#   Country Name Country Code     1960 [YR1960]     1961 [YR1961]  \
# 0  Afghanistan          AFG  62.3693745050559  62.4437034626929
# 1      Albania          ALB                ..                ..
# 2      Algeria          DZA  239.033005807284  209.917177642367
#
#       1962 [YR1962]     1963 [YR1963]     1964 [YR1964]     1965 [YR1965]  \
# 0  60.9503638210144  82.0217375781519  85.5110734102311  105.243195716467
# 1                ..                ..                ..                ..
# 2  169.927013321055  225.823391368412  238.877804941679  253.309059020723
#
#       1966 [YR1966]     1967 [YR1967]  ...     2014 [YR2014]  \
# 0  143.103233209791  167.165674606148  ...  626.512930450573
# 1                ..                ..  ...  4578.63320812155
# 2  241.002571747501  261.366233944322  ...  5516.22944039649
#
#       2015 [YR2015]     2016 [YR2016]     2017 [YR2017]     2018 [YR2018]  \
# 0  566.881132665072  523.053012101752  526.140801271383  492.090632280226
# ...

# %%
# Get a list of columns to rename
columns_to_rename = df_t1.columns[df_t1.columns.str.contains('\[\w+\]')]

# %%
# Rename columns
new_column_names = [col.split(' ')[0] for col in columns_to_rename]
rename_dict = dict(zip(columns_to_rename, new_column_names))
df_t2 = df_t1.rename(columns=rename_dict)

# %%
df_t2.head(3)
# Out:
#   Country Name Country Code              1960              1961  \
# 0  Afghanistan          AFG  62.3693745050559  62.4437034626929
# 1      Albania          ALB                ..                ..
# 2      Algeria          DZA  239.033005807284  209.917177642367
#
#                1962              1963              1964              1965  \
# 0  60.9503638210144  82.0217375781519  85.5110734102311  105.243195716467
# 1                ..                ..                ..                ..
# 2  169.927013321055  225.823391368412  238.877804941679  253.309059020723
#
#                1966              1967  ...              2014  \
# 0  143.103233209791  167.165674606148  ...  626.512930450573
# 1                ..                ..  ...  4578.63320812155
# 2  241.002571747501  261.366233944322  ...  5516.22944039649
#
#                2015              2016              2017              2018  \
# 0  566.881132665072  523.053012101752  526.140801271383  492.090632280226
# ...

# %%
# Remove ".." values from numerical columns
numerical_columns = df_t2.select_dtypes(include='number').columns
df_t2[numerical_columns] = df_t2[numerical_columns].replace('..', pd.NA)

# Convert numerical columns to numeric data type
df_t2[numerical_columns] = df_t2[numerical_columns].apply(pd.to_numeric, errors='ignore')

# Round numerical columns to two decimal points
df_t2[numerical_columns] = df_t2[numerical_columns].round(2)
# Save the modified DataFrame to a new variable
df_t3 = df_t2.copy()
# Out:
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_17564\384605283.py:6: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_t2[numerical_columns] = df_t2[numerical_columns].apply(pd.to_numeric, errors='ignore')

# %%
df_t3.head(5)
# Out:
#      Country Name Country Code              1960              1961  \
# 0     Afghanistan          AFG  62.3693745050559  62.4437034626929
# 1         Albania          ALB              <NA>              <NA>
# 2         Algeria          DZA  239.033005807284  209.917177642367
# 3  American Samoa          ASM              <NA>              <NA>
# 4         Andorra          AND              <NA>              <NA>
#
#                1962              1963              1964              1965  \
# 0  60.9503638210144  82.0217375781519  85.5110734102311  105.243195716467
# 1              <NA>              <NA>              <NA>              <NA>
# 2  169.927013321055  225.823391368412  238.877804941679  253.309059020723
# 3              <NA>              <NA>              <NA>              <NA>
# 4              <NA>              <NA>              <NA>              <NA>
#
#                1966              1967  ...              2014  \
# ...

# %%
df_t3[numerical_columns] = df_t3[numerical_columns].apply(pd.to_numeric, errors='ignore')

# Round numerical columns to two decimal points
df_t3[numerical_columns] = df_t3[numerical_columns].round(2)

df_t4 = df_t3.copy()
# Out:
# C:\Users\Abhik\AppData\Local\Temp\ipykernel_17564\3639577331.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df_t3[numerical_columns] = df_t3[numerical_columns].apply(pd.to_numeric, errors='ignore')

# %%
df_t5 = df_t4.iloc[:-5]

# %%
df_t5.tail(5)
# Out:
#                                    Country Name Country Code  \
# 261                          Sub-Saharan Africa          SSF
# 262  Sub-Saharan Africa (excluding high income)          SSA
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264                         Upper middle income          UMC
# 265                                       World          WLD
#
#                  1960              1961              1962              1963  \
# 261  124.366932197459   128.31965688503  133.332085527768  139.804106912626
# 262  124.342334113495  128.299984981987  133.310223343652  139.779591620867
# 263  124.366932197459  128.319656885031  133.332085527768  139.804106912626
# 264  196.521005341671  182.601951010103  181.093898135676  192.888034223573
# 265  455.598620757168  470.754357809983  494.545424363957  523.157421178679
#
#                  1964              1965              1966              1967  \
# ...

# %%
# Melt the DataFrame to unpivot the year columns into rows
df_t6 = df_t5.melt(id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='Value')

# %%
df_t6.head(5)
# Out:
#      Country Name Country Code  Year             Value
# 0     Afghanistan          AFG  1960  62.3693745050559
# 1         Albania          ALB  1960              <NA>
# 2         Algeria          DZA  1960  239.033005807284
# 3  American Samoa          ASM  1960              <NA>
# 4         Andorra          AND  1960              <NA>

# %%
df_t6.to_csv('test.csv')

# %%
'''columns_to_remove = ['Series Name', 'Series Code']
df.drop(columns=columns_to_remove)
columns_to_rename = df_t1.columns[df_t1.columns.str.contains('\[\w+\]')]
new_column_names = [col.split(' ')[0] for col in columns_to_rename]
rename_dict = dict(zip(columns_to_rename, new_column_names))
numerical_columns = df_t2.select_dtypes(include='number').columns
df_t2[numerical_columns] = df_t2[numerical_columns].replace('..', pd.NA)

#### Convert numerical columns to numeric data type
df_t2[numerical_columns] = df_t2[numerical_columns].apply(pd.to_numeric, errors='ignore')

# Round numerical columns to two decimal points
df_t2[numerical_columns] = df_t2[numerical_columns].round(2)

df_t5 = df_t4.iloc[:-5]

df_t6 = df_t5.melt(id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='Value')
'''

# %% [markdown]
# ## All in one script

# %%
import pandas as pd

# Read the CSV file into df dataframe
df = pd.read_csv('emissions.csv')

# Remove specified columns
columns_to_remove = ['Series Name', 'Series Code']
df.drop(columns=columns_to_remove, inplace=True)

# Rename columns
columns_to_rename = df.columns[df.columns.str.contains('\[\w+\]')]
new_column_names = [col.split(' ')[0] for col in columns_to_rename]
rename_dict = dict(zip(columns_to_rename, new_column_names))
df.rename(columns=rename_dict, inplace=True)

# Replace '..' values with NaN
numerical_columns = df.select_dtypes(include='number').columns
df[numerical_columns] = df[numerical_columns].replace('..', 0 )

# Convert numerical columns to numeric data type
df[numerical_columns] = df[numerical_columns].apply(pd.to_numeric)

# Round numerical columns to two decimal points
# df[numerical_columns] = df[numerical_columns].round(2)

# Remove last 5 rows
df = df.iloc[:-5]

# Melt the DataFrame
data = df.melt(id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='Value')
# data['Value'] = data['Value'].round(2)
# round(data.Value(), 2)

data['Value'] = pd.to_numeric(data['Value'], errors='coerce')  # Convert to numeric, coercing errors
data['Value'] = data['Value'].round(2)  # Round off to two decimal places

# Save the formatted data into a new dataframe named "data"
data.to_csv('emissions_modified.csv', index=False)

# %% [markdown]
# ## Merging two files

# %%
import pandas as pd

# Read the modified CSV files
electricity_df = pd.read_csv('electricity_access_modified.csv')
agricultural_df = pd.read_csv('agricultural_land_modified.csv')

# Merge the two DataFrames based on "Country Code" and "Year"
merged_df = pd.merge(electricity_df, agricultural_df, on=['Country Code', 'Year'], how='left')

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('electricity_&_agriculture.csv', index=False)

# %% [markdown]
# ## Picking all files from a single location to merge

# %%
import pandas as pd
import os

# Directory containing the CSV files
directory = r'D:\Main\My Practice and experiments\My Practice LAB\Python\2024\Own Projects\Data_Transformation\Converted'

# List to store DataFrames
dataframes = []

# Iterate over files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        dataframes.append(df)

# Merge the DataFrames based on "Country Code" and "Year"
merged_df = dataframes[0]  # Start with the first DataFrame
for df, filename in zip(dataframes[1:], os.listdir(directory)[1:]):
    # Extract the filename without extension
    filename = os.path.splitext(filename)[0]
    # Rename columns in the current DataFrame with filename suffixes
    df.columns = [f'{col}_{filename}' if col not in ['Country Code', 'Year'] else col for col in df.columns]
    # Merge with the main DataFrame
    merged_df = pd.merge(merged_df, df, on=['Country Code', 'Year'], how='left')

# Save the merged DataFrame to a new CSV file
merged_df.to_csv('merged_data.csv', index=False)
