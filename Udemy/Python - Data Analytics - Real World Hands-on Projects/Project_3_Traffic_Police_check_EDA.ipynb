# %% [markdown]
# # Working on Real Project with Python

# %% [markdown]
# ## (A part of Big Data Analysis)

# %% [markdown]
# ***

# %% [markdown]
# # Police Dataset
# ***
# Here,
#
# The data from a Police Check Post is given.
#
# This data is available as a CSV file. We are going to analyze this data set using the Pandas DataFrame.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\Main\My Practice and experiments\My Practice LAB\Python\2023\Udemy\Python - Data Analytics - Real World Hands-on Projects\Project_3\police.csv")

# %%
data.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
data
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
for column in data.columns:
    column_rows = data[column].count()
    print(f'The total number of rows in column "{column}" is: {column_rows}')
# Out:
# The total number of rows in column "stop_date" is: 91741
# The total number of rows in column "stop_time" is: 91741
# The total number of rows in column "county_name" is: 0
# The total number of rows in column "driver_gender" is: 86406
# The total number of rows in column "driver_age_raw" is: 86414
# The total number of rows in column "driver_age" is: 86120
# The total number of rows in column "driver_race" is: 86408
# The total number of rows in column "violation_raw" is: 86408
# The total number of rows in column "violation" is: 86408
# The total number of rows in column "search_conducted" is: 91741
# The total number of rows in column "search_type" is: 3196
# The total number of rows in column "stop_outcome" is: 86408
# The total number of rows in column "is_arrested" is: 86408
# The total number of rows in column "stop_duration" is: 86408
# The total number of rows in column "drugs_related_stop" is: 91741

# %% [markdown]
# ----

# %% [markdown]
# ### Instruction ( For Data Cleaning )
#
# # 1. Remove the column that only contains missing values

# %%
# df.isnull().sum()

# df.drop( columns = 'Column_name' , inplace = True )

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
data.drop( columns = 'county_name', inplace = True)

# %%
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %% [markdown]
# ----

# %% [markdown]
# ### Question ( Based on Filtering + Value Counts )
#
# # 2. For Speeding , were Men or Women stopped more often ?

# %%
# df[df.Column_1 == 'Element/Value'].Column_2.value_counts()

# %%
data.head()
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0  2005-01-02     01:55             M          1985.0        20.0       White
# 1  2005-01-18     08:15             M          1965.0        40.0       White
# 2  2005-01-23     23:15             M          1972.0        33.0       White
# 3  2005-02-20     17:15             M          1986.0        19.0       White
# 4  2005-03-14     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
# ...

# %%
data[data.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# driver_gender
# M    32979
# F    15482
# Name: count, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# ### Question ( Groupby )
# # 3. Does gender affect who gets searched during a stop ?

# %%
data.head()
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0  2005-01-02     01:55             M          1985.0        20.0       White
# 1  2005-01-18     08:15             M          1965.0        40.0       White
# 2  2005-01-23     23:15             M          1972.0        33.0       White
# 3  2005-02-20     17:15             M          1986.0        19.0       White
# 4  2005-03-14     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
# ...

# %%
# df.groupby('Column_1').Column_2.sum()

# %%
data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     471
# M    2725
# Name: search_conducted, dtype: int64

# %%
data.search_conducted.value_counts()
# Out:
# search_conducted
# False    88545
# True      3196
# Name: count, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# ### Question ( mapping + data-type casting )
#
# # 4. What is the mean stop_duration ?

# %%
# df['Column_name'] = df['Column_name'].map( { old:new , old:new} )

# df['Column_name'].mean()

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
data.stop_duration.value_counts()
# Out:
# stop_duration
# 0-15 Min     69543
# 16-30 Min    13635
# 30+ Min       3228
# 2                1
# 1                1
# Name: count, dtype: int64

# %%
data['stop_duration']= data['stop_duration'].map( {'0-15 Min' : 7.5 ,  '16-30 Min' : 24 , '30+ Min' : 45 })

# %%
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data['stop_duration'].mean().round(2)
# Out:
# 11.5

# %% [markdown]
# -----

# %% [markdown]
# ### Question ( Groupby , Describe )
# # 5. Compare the age distributions for each violation

# %%
# df.groupby('Column_1').Column_2.describe()

# %%
data.head()
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0  2005-01-02     01:55             M          1985.0        20.0       White
# 1  2005-01-18     08:15             M          1965.0        40.0       White
# 2  2005-01-23     23:15             M          1972.0        33.0       White
# 3  2005-02-20     17:15             M          1986.0        19.0       White
# 4  2005-03-14     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
# ...

# %%
data.groupby('violation').driver_age.describe().round(2)
# Out:
#                        count   mean    std   min   25%   50%   75%   max
# violation
# Equipment            11007.0  31.78  11.40  16.0  23.0  28.0  38.0  89.0
# Moving violation     16164.0  36.12  13.19  15.0  25.0  33.0  46.0  99.0
# Other                 4204.0  39.54  13.03  16.0  28.0  39.0  49.0  87.0
# Registration/plates   3427.0  32.80  11.03  16.0  24.0  30.0  40.0  74.0
# Seat belt             2952.0  32.21  11.21  17.0  24.0  29.0  38.0  77.0
# Speeding             48361.0  33.53  12.82  15.0  23.0  30.0  42.0  90.0
