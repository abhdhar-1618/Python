# %% [markdown]
# # Working on Real Project with Python on 'COVID-19 Dataset'

# %% [markdown]
# ## (A part of Big Data Analysis)

# %% [markdown]
# ----

# %% [markdown]
# # COVID-19 SMALL DATASET

# %% [markdown]
# -----

# %% [markdown]
# We have taken a small dataset of Covid-19, just for your understaning purpose. You have to work on the original dataset which contains about 19000 rows.

# %% [markdown]
# The data used here is till 29-April-2020 and has records as on 29-April-2020.

# %% [markdown]
# This data is available as a CSV file, downloaded from Kaggle.

# %% [markdown]
# We will analyze this data using the Pandas DataFrame.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\Main\My Practice and experiments\My Practice LAB\Python\2023\Udemy\Python - Data Analytics - Real World Hands-on Projects\Project_4\C_19.csv")

# %%
data
# Out:
#           Date     State         Region  Confirmed  Deaths  Recovered  \
# 0    4/29/2020       NaN    Afghanistan       1939      60        252
# 1    4/29/2020       NaN        Albania        766      30        455
# 2    4/29/2020       NaN        Algeria       3848     444       1702
# 3    4/29/2020       NaN        Andorra        743      42        423
# 4    4/29/2020       NaN         Angola         27       2          7
# ..         ...       ...            ...        ...     ...        ...
# 316  4/29/2020   Wyoming  United States        545       7          0
# 317  4/29/2020  Xinjiang          China         76       3         73
# 318  4/29/2020     Yukon         Canada         11       0          0
# 319  4/29/2020    Yunnan          China        185       2        181
# 320  4/29/2020  Zhejiang          China       1268       1       1263
#
#     Continents
# 0         Asia
# 1       Europe
# 2       Africa
# 3       Europe
# 4       Africa
# ..         ...
# 316   Americas
# 317       Asia
# 318   Americas
# 319       Asia
# 320       Asia
#
# [321 rows x 7 columns]

# %%
# 1. 
# df.count()
# df.isnull().sum()

# %%
data.count()

# Null Values means Missing Values
# Out:
# Date          321
# State         140
# Region        321
# Confirmed     321
# Deaths        321
# Recovered     321
# Continents    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date            0
# State         181
# Region          0
# Confirmed       0
# Deaths          0
# Recovered       0
# Continents      0
# dtype: int64

# %%
# 2.
# import seaborn as sns
# import matplotlib.pyplot as plt
# sns.heatmap(df.isnull())
# plt.show()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ### Q.1 ) Show the number of Confirmed , Deaths and Recovered cases in each Region.

# %%
#df.groupby('Region').sum().head(50)
#df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
#df.groupby('Region')['Confirmed', 'Recovered'].sum()

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered Continents
# 0  4/29/2020   NaN  Afghanistan       1939      60        252       Asia
# 1  4/29/2020   NaN      Albania        766      30        455     Europe

# %%
data.groupby('Region').sum().head(20)
# Out:
#                                                                   Date  \
# Region
# Afghanistan                                                  4/29/2020
# Albania                                                      4/29/2020
# Algeria                                                      4/29/2020
# Andorra                                                      4/29/2020
# Angola                                                       4/29/2020
# Antigua and Barbuda                                          4/29/2020
# Argentina                                                    4/29/2020
# Armenia                                                      4/29/2020
# Australia            4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                      4/29/2020
# Azerbaijan                                                   4/29/2020
# Bahamas                                                      4/29/2020
# Bahrain                                                      4/29/2020
# Bangladesh                                                   4/29/2020
# Barbados                                                     4/29/2020
# Belarus                                                      4/29/2020
# Belgium                                                      4/29/2020
# Belize                                                       4/29/2020
# Benin                                                        4/29/2020
# Bhutan                                                       4/29/2020
#
#                                                                  State  \
# Region
# Afghanistan                                                          0
# Albania                                                              0
# Algeria                                                              0
# Andorra                                                              0
# Angola                                                               0
# Antigua and Barbuda                                                  0
# Argentina                                                            0
# Armenia                                                              0
# Australia            Australian Capital TerritoryNew South WalesNor...
# Austria                                                              0
# Azerbaijan                                                           0
# Bahamas                                                              0
# Bahrain                                                              0
# Bangladesh                                                           0
# Barbados                                                             0
# Belarus                                                              0
# Belgium                                                              0
# Belize                                                               0
# Benin                                                                0
# Bhutan                                                               0
#
#                      Confirmed  Deaths  Recovered  \
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# Benin                       64       1         33
# Bhutan                       7       0          5
#
#                                                             Continents
# Region
# Afghanistan                                                       Asia
# Albania                                                         Europe
# Algeria                                                         Africa
# Andorra                                                         Europe
# Angola                                                          Africa
# Antigua and Barbuda                                           Americas
# Argentina                                                     Americas
# Armenia                                                           Asia
# Australia            OceaniaOceaniaOceaniaOceaniaOceaniaOceaniaOcea...
# Austria                                                         Europe
# Azerbaijan                                                        Asia
# Bahamas                                                       Americas
# Bahrain                                                           Asia
# Bangladesh                                                        Asia
# Barbados                                                      Americas
# Belarus                                                         Europe
# Belgium                                                         Europe
# Belize                                                        Americas
# Benin                                                           Africa
# Bhutan                                                            Asia

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# United States     1039909
# Spain              236899
# Italy              203591
# France             166543
# United Kingdom     166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# China               82862
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')[['Confirmed', 'Deaths', 'Recovered']].sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# ### Q2) Remove all the records where Confirmed Cases is Less Than 10.

# %%
#df.Confirmed < 10
#df[df.Confirmed < 10]
#df[~(df.Confirmed < 10)]
#df = df[~(df.Confirmed < 10)]

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered Continents
# 0  4/29/2020   NaN  Afghanistan       1939      60        252       Asia
# 1  4/29/2020   NaN      Albania        766      30        455     Europe

# %%
data = data[~(data.Confirmed < 10)] # To remove the records satisfying a particular condition

# %%
data.head(20).sort_values(by='Confirmed', ascending=True)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered  \
# 16  4/29/2020   NaN                  Belize         18       2          9
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 4   4/29/2020   NaN                  Angola         27       2          7
# 17  4/29/2020   NaN                   Benin         64       1         33
# 13  4/29/2020   NaN                Barbados         80       7         39
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 1   4/29/2020   NaN                 Albania        766      30        455
# 19  4/29/2020   NaN                 Bolivia       1110      59        117
# 20  4/29/2020   NaN  Bosnia and Herzegovina       1677      65        710
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 12  4/29/2020   NaN              Bangladesh       7103     163        150
# 14  4/29/2020   NaN                 Belarus      13181      84       2072
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 15  4/29/2020   NaN                 Belgium      47859    7501      11283
#
#    Continents
# 16   Americas
# 5    Americas
# 4      Africa
# 17     Africa
# 13   Americas
# 10   Americas
# 3      Europe
# 1      Europe
# 19   Americas
# 20     Europe
# 9        Asia
# 7        Asia
# 0        Asia
# 11       Asia
# 2      Africa
# 6    Americas
# 12       Asia
# 14     Europe
# 8      Europe
# 15     Europe

# %% [markdown]
# ### Q.3) In which Region, maximum number of Confirmed cases were recorded ?

# %%
#data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered Continents
# 0  4/29/2020   NaN  Afghanistan       1939      60        252       Asia
# 1  4/29/2020   NaN      Albania        766      30        455     Europe

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# United States     1039909
# Spain              236899
# Italy              203591
# France             166536
# United Kingdom     166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# China               82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### Q.4) In which Region, minimum number of Deaths cases were recorded ?

# %%
#df.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered Continents
# 0  4/29/2020   NaN  Afghanistan       1939      60        252       Asia
# 1  4/29/2020   NaN      Albania        766      30        455     Europe

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Cambodia                            0
# Namibia                             0
# Nepal                               0
# Mozambique                          0
# Rwanda                              0
# Grenada                             0
# Saint Kitts and Nevis               0
# Saint Lucia                         0
# Saint Vincent and the Grenadines    0
# Central African Republic            0
# Madagascar                          0
# Seychelles                          0
# Fiji                                0
# Eritrea                             0
# South Sudan                         0
# Dominica                            0
# Vietnam                             0
# Laos                                0
# Uganda                              0
# Mongolia                            0
# Macau                               0
# Timor-Leste                         0
# Holy See                            0
# Brunei Darussalam                   1
# Gambia                              1
# Liechtenstein                       1
# Burundi                             1
# Cabo Verde                          1
# Equatorial Guinea                   1
# Eswatini                            1
# Botswana                            1
# Guinea-Bissau                       1
# Suriname                            1
# Benin                               1
# Maldives                            1
# Djibouti                            2
# Chad                                2
# Libya                               2
# Angola                              2
# Belize                              2
# West Bank and Gaza                  2
# Nicaragua                           3
# Syria                               3
# Malawi                              3
# Antigua and Barbuda                 3
# Gabon                               3
# Zambia                              3
# Ethiopia                            3
# Zimbabwe                            4
# Malta                               4
# Name: Deaths, dtype: int64

# %% [markdown]
# ### Q.5) How many Confirmed , Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
#df[df.Region == 'Country_name']

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered Continents
# 0  4/29/2020   NaN  Afghanistan       1939      60        252       Asia
# 1  4/29/2020   NaN      Albania        766      30        455     Europe

# %%
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered Continents
# 74  4/29/2020   NaN  India      33062    1079       8437       Asia

# %%
data[data.Region == 'Yemen']
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered, Continents]
# Index: []

# %%
data[data.Region == 'US']
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered, Continents]
# Index: []

# %% [markdown]
# ### Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
#df.sort_values(by= ['Confirmed'] , ascending = True)

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered Continents
# 0  4/29/2020   NaN  Afghanistan       1939      60        252       Asia
# 1  4/29/2020   NaN      Albania        766      30        455     Europe

# %%
data.sort_values( by = ['Confirmed'] , ascending = True).head(50)
# Out:
#           Date                         State  \
# 156  4/29/2020                           NaN
# 70   4/29/2020                           NaN
# 59   4/29/2020                           NaN
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 256  4/29/2020                    Montserrat
# 144  4/29/2020                           NaN
# 27   4/29/2020                           NaN
# 306  4/29/2020      Turks and Caicos Islands
# 118  4/29/2020                           NaN
# 215  4/29/2020                Grand Princess
# 206  4/29/2020   Falkland Islands (Malvinas)
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 114  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 260  4/29/2020                 New Caledonia
# 16   4/29/2020                           NaN
# 55   4/29/2020                           NaN
# 281  4/29/2020                       Qinghai
# 90   4/29/2020                           NaN
# 64   4/29/2020                           NaN
# 21   4/29/2020                           NaN
# 5    4/29/2020                           NaN
# 163  4/29/2020                           NaN
# 279  4/29/2020          Prince Edward Island
# 4    4/29/2020                           NaN
# 271  4/29/2020            Northern Territory
# 180  4/29/2020                           NaN
# 152  4/29/2020                           NaN
# 100  4/29/2020                           NaN
# 300  4/29/2020                     St Martin
# 110  4/29/2020                           NaN
# 51   4/29/2020                           NaN
# 159  4/29/2020                           NaN
# 244  4/29/2020                         Macau
# 204  4/29/2020  Diamond Princess cruise ship
# 31   4/29/2020                           NaN
# 32   4/29/2020                           NaN
# 310  4/29/2020                Virgin Islands
# 115  4/29/2020                           NaN
# 210  4/29/2020              French Polynesia
# 94   4/29/2020                           NaN
# 17   4/29/2020                           NaN
# 196  4/29/2020                Cayman Islands
# 296  4/29/2020                  Sint Maarten
# 267  4/29/2020                       Ningxia
#
#                                Region  Confirmed  Deaths  Recovered Continents
# 156                          Suriname         10       1          8   Americas
# 70                           Holy See         10       0          2     Europe
# 59                             Gambia         10       1          8     Africa
# 318                            Canada         11       0          0   Americas
# 217                           Denmark         11       0         11     Europe
# 256                    United Kingdom         11       1          2     Europe
# 144                        Seychelles         11       0          6     Africa
# 27                            Burundi         11       1          4     Africa
# 306                    United Kingdom         12       1          5     Europe
# 118                         Nicaragua         13       3          7   Americas
# 215                            Canada         13       0          0   Americas
# 206                    United Kingdom         13       0         11     Europe
# 270                     United States         14       2          0   Americas
# 136             Saint Kitts and Nevis         15       0          4   Americas
# 138  Saint Vincent and the Grenadines         16       0          8   Americas
# 45                           Dominica         16       0         13   Americas
# 201                       Netherlands         16       1         13     Europe
# 114                           Namibia         16       0          8     Africa
# 137                       Saint Lucia         17       0         15   Americas
# 260                            France         18       0         17     Europe
# 16                             Belize         18       2          9   Americas
# 55                               Fiji         18       0         12    Oceania
# 281                             China         18       0         18       Asia
# 90                               Laos         19       0          7       Asia
# 64                            Grenada         20       0         13   Americas
# 21                           Botswana         23       1          5     Africa
# 5                 Antigua and Barbuda         24       3         11   Americas
# 163                       Timor-Leste         24       0          6       Asia
# 279                            Canada         27       0          0   Americas
# 4                              Angola         27       2          7     Africa
# 271                         Australia         28       0         25    Oceania
# 180                          Zimbabwe         32       4          5     Africa
# 152                       South Sudan         34       0          0     Africa
# 100                            Malawi         36       3          7     Africa
# 300                            France         38       3         24     Europe
# 110                          Mongolia         38       0         10       Asia
# 51                            Eritrea         39       0         19     Africa
# 159                             Syria         43       3         21       Asia
# 244                             Macau         45       0         34       Asia
# 204                     United States         49       0          0   Americas
# 31           Central African Republic         50       0         10     Africa
# 32                               Chad         52       2         19     Africa
# 310                     United States         57       4          0   Americas
# 115                             Nepal         57       0         16       Asia
# 210                            France         58       0         50     Europe
# 94                              Libya         61       2         18     Africa
# 17                              Benin         64       1         33     Africa
# 196                    United Kingdom         73       1         10     Europe
# 296                       Netherlands         75      13         33     Europe
# 267                             China         75       0         75       Asia

# %% [markdown]
# ### Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
#df.sort_values(by= ['Recovered'] , ascending = False)

# %%
data.sort_values( by = ['Recovered'] , ascending = False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei                 China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 78   4/29/2020              NaN               Ireland      20253    1190
# 8    4/29/2020              NaN               Austria      15402     580
# 107  4/29/2020              NaN                Mexico      17799    1732
# 15   4/29/2020              NaN               Belgium      47859    7501
# 134  4/29/2020              NaN                Russia      99399     972
# 128  4/29/2020              NaN                  Peru      33931     943
# 151  4/29/2020              NaN           South Korea      10765     247
# 74   4/29/2020              NaN                 India      33062    1079
# 79   4/29/2020              NaN                Israel      15834     215
# 33   4/29/2020              NaN                 Chile      14885     216
# 42   4/29/2020              NaN               Denmark       9008     443
# 101  4/29/2020              NaN              Malaysia       5945     100
# 133  4/29/2020              NaN               Romania      11978     693
# 124  4/29/2020              NaN              Pakistan      15525     343
# 97   4/29/2020              NaN            Luxembourg       3769      89
# 41   4/29/2020              NaN        Czech Republic       7579     227
# 130  4/29/2020              NaN                Poland      12640     624
# 141  4/29/2020              NaN          Saudi Arabia      21402     157
# 56   4/29/2020              NaN               Finland       4906     206
# 162  4/29/2020              NaN              Thailand       2947      54
# 83   4/29/2020              NaN                 Japan      13895     413
# 171  4/29/2020              NaN  United Arab Emirates      11929      98
# 264  4/29/2020  New South Wales             Australia       3016      40
# 150  4/29/2020              NaN          South Africa       5350     103
# 14   4/29/2020              NaN               Belarus      13181      84
# 2    4/29/2020              NaN               Algeria       3848     444
# 73   4/29/2020              NaN               Iceland       1797      10
# 47   4/29/2020              NaN               Ecuador      24675     883
# 220  4/29/2020        Guangdong                 China       1588       8
# 131  4/29/2020              NaN              Portugal      24505     973
# 11   4/29/2020              NaN               Bahrain       2921       8
# 34   4/29/2020              NaN              Colombia       6207     278
# 75   4/29/2020              NaN             Indonesia       9771     784
# 88   4/29/2020              NaN                Kuwait       3740      24
# 77   4/29/2020              NaN                  Iraq       2003      92
# 48   4/29/2020              NaN                 Egypt       5268     380
# 309  4/29/2020         Victoria             Australia       1361      18
# 38   4/29/2020              NaN               Croatia       2062      67
# 9    4/29/2020              NaN            Azerbaijan       1766      23
# 320  4/29/2020         Zhejiang                 China       1268       1
# 227  4/29/2020            Henan                 China       1276      22
#
#      Recovered Continents
# 153     132929     Europe
# 61      120400     Europe
# 76       73791       Asia
# 80       71252     Europe
# 229      63616       Asia
# 57       48228     Europe
# 167      44040       Asia
# 22       34132   Americas
# 158      22600     Europe
# 78       13386     Europe
# 8        12779     Europe
# 107      11423   Americas
# 15       11283     Europe
# 134      10286     Europe
# 128      10037   Americas
# 151       9059       Asia
# 74        8437       Asia
# 79        8233       Asia
# 33        8057   Americas
# 42        6366     Europe
# 101       4087       Asia
# 133       3569     Europe
# 124       3425       Asia
# 97        3134     Europe
# 41        3108     Europe
# 130       3025     Europe
# 141       2953       Asia
# 56        2800     Europe
# 162       2665       Asia
# 83        2368       Asia
# 171       2329       Asia
# 264       2284    Oceania
# 150       2073     Africa
# 14        2072     Europe
# 2         1702     Africa
# 73        1656     Europe
# 47        1557   Americas
# 220       1557       Asia
# 131       1470     Europe
# 11        1455       Asia
# 34        1411   Americas
# 75        1391       Asia
# 88        1389       Asia
# 77        1346       Asia
# 48        1335     Africa
# 309       1291    Oceania
# 38        1288     Europe
# 9         1267       Asia
# 320       1263       Asia
# 227       1254       Asia

# %% [markdown]
# ---
